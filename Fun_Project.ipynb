# %% [markdown]
# # **NUMBER GUESSING GAME (FUN PROJECT)**

# %%
# ===============================
# NUMBER GUESSING GAME (FUN PROJECT)
# ===============================

import random

print("Welcome to Number Guessing Game")
print("You have only 3 attempts!")

number = random.randint(1, 100)
attempts = 0
max_attempts = 3

while attempts < max_attempts:
    guess = int(input("Enter your guess: "))
    attempts += 1

    if guess < number:
        print("Too low!")
    elif guess > number:
        print("Too high!")
    else:
        print(f" Correct! You guessed in {attempts} attempts.")
        break

# If user fails after 3 attempts
if attempts == max_attempts and guess != number:
    print(f" Game Over! The correct number was {number}")
# Out:
# Welcome to Number Guessing Game
# You have only 3 attempts!
# Enter your guess: 88
# Too low!
# Enter your guess: 66
# Too low!
# Enter your guess: 1000
# Too high!
#  Game Over! The correct number was 99
